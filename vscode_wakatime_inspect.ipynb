# %%
# Fetch status bar API definitions from zed-extension-api
import urllib.request
url = 'https://raw.githubusercontent.com/zed-dev/zed-extension-api/main/src/status_bar.rs'
print('Fetching', url)
print(urllib.request.urlopen(url).read().decode('utf-8').splitlines()[:60])
# Out:
# Fetching https://raw.githubusercontent.com/zed-dev/zed-extension-api/main/src/status_bar.rs
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       3 url = 'https://raw.githubusercontent.com/zed-dev/zed-extension-api/main/src/status_bar.rs'
#       4 print('Fetching', url)
# ----> 5 print(urllib.request.urlopen(url).read().decode('utf-8').splitlines()[:60])
#
# File /usr/local/python/3.12.1/lib/python3.12/urllib/request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File /usr/local/python/3.12.1/lib/python3.12/urllib/request.py:521, in OpenerDirector.open(self, fullurl, data, timeout)
#     519 for processor in self.process_response.get(protocol, []):
#     520     meth = getattr(processor, meth_name)
# ...

# %%
# Try listing files in zed-extension-api/src by parsing GitHub HTML
import urllib.request, re
url = 'https://github.com/zed-dev/zed-extension-api/tree/main/src'
html = urllib.request.urlopen(url).read().decode('utf-8')
# find .rs filenames in hrefs
files = re.findall(r'href="[^"]+/blob/main/src/([^"]+\.rs)"', html)
print(files)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       2 import urllib.request, re
#       3 url = 'https://github.com/zed-dev/zed-extension-api/tree/main/src'
# ----> 4 html = urllib.request.urlopen(url).read().decode('utf-8')
#       5 # find .rs filenames in hrefs
#       6 files = re.findall(r'href="[^"]+/blob/main/src/([^"]+\.rs)"', html)
#
# File /usr/local/python/3.12.1/lib/python3.12/urllib/request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File /usr/local/python/3.12.1/lib/python3.12/urllib/request.py:521, in OpenerDirector.open(self, fullurl, data, timeout)
#     519 for processor in self.process_response.get(protocol, []):
#     520     meth = getattr(processor, meth_name)
# --> 521     response = meth(req, response)
# ...

# %%
# Inspecting the `wakatime/vscode-wakatime` Repository

This notebook walks through the VS Code extension source to see how it displays coding time in the status bar.
</VSCode.Cell>

<VSCode.Cell language="python">
# Section 1: Clone and Install Repository
# !git clone https://github.com/wakatime/vscode-wakatime /workspaces/zed-wakatime/vscode-wakatime-repo
# !ls -R /workspaces/zed-wakatime/vscode-wakatime-repo | head
</VSCode.Cell>

<VSCode.Cell language="python">
# Section 2: Explore Project Structure
# !find /workspaces/zed-wakatime/vscode-wakatime-repo -maxdepth 2 -type d -print
# !find /workspaces/zed-wakatime/vscode-wakatime-repo -maxdepth 2 -name "*.ts" | head
</VSCode.Cell>

<VSCode.Cell language="python">
# Section 3: Setup Development Environment
print("Open the cloned repo in VSCode and install recommended extensions like 'ESLint' and 'TypeScript'.")
</VSCode.Cell>

<VSCode.Cell language="python">
# Section 4: Debug and Run Extension in VSCode
print("Use the 'Launch Extension' debug configuration; pressing F5 will open a new VSCode window with the extension loaded.")
</VSCode.Cell>

<VSCode.Cell language="python">
# Section 5: Examine Core Files
print(open('/workspaces/zed-wakatime/vscode-wakatime-repo/src/extension.ts').read().splitlines()[:60])
</VSCode.Cell>

<VSCode.Cell language="python">
# Section 6: Analyze Activation and Events
import json
pkg = '/workspaces/zed-wakatime/vscode-wakatime-repo/package.json'
data = json.load(open(pkg))
print('activationEvents', data.get('activationEvents'))
print('commands', [c['command'] for c in data.get('contributes', {}).get('commands', [])])
</VSCode.Cell>

<VSCode.Cell language="python">
# Section 7: Work with API and Network Requests
print('Search source for "wakatime.com" and HTTP calls:')
import os
for root,_,files in os.walk('/workspaces/zed-wakatime/vscode-wakatime-repo/src'):
    for f in files:
        if f.endswith('.ts'):
            path = os.path.join(root,f)
            for line in open(path):
                if 'wakatime.com' in line or 'fetch' in line:
                    print(path, line.strip())
